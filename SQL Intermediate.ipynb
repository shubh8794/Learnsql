# %% [markdown]
# # Analyzing credit card complaints data

# %% [markdown]
# Following blog
# https://www.dataquest.io/blog/sql-intermediate

# %%
import pandas as pd

# psycopg2 lets us easily run commands against our db

import psycopg2
conn = psycopg2.connect("dbname=consumer_complaints user=oracle")
conn.autocommit = True
cur = conn.cursor()

# %%
def run_command(command):
    cur.execute(command)
    return cur.statusmessage

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://oracle@localhost/consumer_complaints')

# %%
def run_query(query):
    return pd.read_sql_query(query,con=engine)

# %% [markdown]
# ## CREDIT CARD Complaints

# %%
query = 'SELECT * FROM credit_card_complaints LIMIT 5;'
run_query(query)
# Out:
#   complaint_id date_received      product sub_product  \
# 0       469026    2013-07-29  Credit card        None
# 1       469131    2013-07-29  Credit card        None
# 2       479990    2013-07-29  Credit card        None
# 3       475777    2013-07-29  Credit card        None
# 4       469473    2013-07-29  Credit card        None
#
#                            issue sub_issue consumer_complaint_narrative  \
# 0              Billing statement      None                         None
# 1           APR or interest rate      None                         None
# 2             Delinquent account      None                         None
# 3               Billing disputes      None                         None
# 4  Credit line increase/decrease      None                         None
#
#   company_public_response              company state zip_code            tags  \
# 0                    None             Citibank    OH    45247            None
# 1                    None  Synchrony Financial    WA    98548            None
# 2                    None                 Amex    TX    78232            None
# 3                    None          Capital One    FL    32226   Servicemember
# 4                    None             Citibank    WI    53066  Older American
#
#   consumer_consent_provided submitted_via   date_sent  \
# 0                       N/A      Referral  2013-07-30
# 1                       N/A           Web  2013-07-29
# 2                       N/A           Web  2013-07-29
# 3                       N/A           Web  2013-07-29
# 4                       N/A         Phone  2013-07-30
#
#   company_response_to_consumer timely_response consumer_disputed
# 0      Closed with explanation             Yes               Yes
# 1  Closed with monetary relief             Yes                No
# 2  Closed with monetary relief             Yes                No
# 3      Closed with explanation             Yes                No
# 4      Closed with explanation             Yes               Yes

# %% [markdown]
# ## Bank Account Complaints

# %%
query = 'SELECT * FROM bank_account_complaints LIMIT 5;'
run_query(query)
# Out:
#   complaint_id date_received                  product  \
# 0       468889    2013-07-29  Bank account or service
# 1       468879    2013-07-29  Bank account or service
# 2       468949    2013-07-29  Bank account or service
# 3       468981    2013-07-29  Bank account or service
# 4       469185    2013-07-29  Bank account or service
#
#                   sub_product                                    issue  \
# 0            Checking account                Using a debit or ATM card
# 1            Checking account  Account opening, closing, or management
# 2            Checking account                 Deposits and withdrawals
# 3            Checking account                 Deposits and withdrawals
# 4  Other bank product/service                 Deposits and withdrawals
#
#   sub_issue consumer_complaint_narrative company_public_response  \
# 0      None                         None                    None
# 1      None                         None                    None
# 2      None                         None                    None
# 3      None                         None                    None
# 4      None                         None                    None
#
#                  company state zip_code            tags  \
# 0  Wells Fargo & Company    CA    95992  Older American
# 1      Santander Bank US    NY    10065            None
# 2  Wells Fargo & Company    GA    30084            None
# 3        Bank of America    TX    75025            None
# 4  Wells Fargo & Company    CA    96088            None
#
#   consumer_consent_provided submitted_via   date_sent  \
# 0                       N/A           Web  2013-07-31
# 1                       N/A           Fax  2013-07-31
# 2                       N/A           Web  2013-07-30
# 3                       N/A           Web  2013-07-30
# 4                       N/A           Web  2013-08-01
#
#   company_response_to_consumer timely_response consumer_disputed
# 0      Closed with explanation             Yes                No
# 1                       Closed             Yes                No
# 2      Closed with explanation             Yes                No
# 3      Closed with explanation             Yes                No
# 4      Closed with explanation             Yes                No

# %% [markdown]
# How many records in each table have null values for the consumer complaint narrative field

# %%
# credit card complaints
query = 'SELECT count(*) FROM credit_card_complaints WHERE consumer_complaint_narrative IS NOT NULL;'
run_query(query)
# Out:
#    count
# 0  17433

# %%
query ='SELECT count(*) FROM credit_card_complaints WHERE consumer_complaint_narrative IS NULL;'
run_query(query)
# Out:
#    count
# 0  70285

# %%
# bank account complaints
query = 'SELECT count(*) FROM bank_account_complaints WHERE consumer_complaint_narrative IS NOT NULL;'
run_query(query)
# Out:
#    count
# 0  13860

# %% [markdown]
# **VIEW**
#
#
# view is essentially a logical representation of a query’s result. It behaves like a traditional table where you can select values, but you cannot insert into, update, or delete from it. Here are a few benefits of using views:
#
# **Reusability** – Views can be used to reuse complex queries that are frequently used.
#
# **Security** – Views are often made accessible to certain users so that they cannot view the underlying tables and only relevant data is available.
#
# **Query Performance** – Sometimes, writing complex queries consisting of several subqueries and aggregations will utilize a large amount of resources.

# %%
command = 'CREATE VIEW credit_card_w_complaints AS SELECT * FROM credit_card_complaints WHERE consumer_complaint_narrative IS NOT NULL;'
run_command(command)
# Out:
# 'CREATE VIEW'

# %%
command = '''
CREATE VIEW credit_card_wo_complaints as
    SELECT * FROM credit_card_complaints
    WHERE consumer_complaint_narrative IS NULL;
'''
run_command(command)
# Out:
# 'CREATE VIEW'

# %%
command = '''
CREATE VIEW bank_account_w_complaints AS
    SELECT * FROM bank_account_complaints
    WHERE consumer_complaint_narrative IS NOT
 NULL;
'''
run_command(command)
# Out:
# 'CREATE VIEW'

# %%
command = '''
CREATE VIEW bank_account_wo_complaints AS
    SELECT * FROM bank_account_complaints
    WHERE consumer_complaint_narrative IS
 NULL;
'''
run_command(command)
# Out:
# 'CREATE VIEW'

# %%
query = 'SELECT * FROM bank_account_w_complaints LIMIT 5;'
run_query(query)
# Out:
#   complaint_id date_received                  product  \
# 0      1297629    2015-03-24  Bank account or service
# 1      1297676    2015-03-24  Bank account or service
# 2      1297773    2015-03-24  Bank account or service
# 3      1297972    2015-03-24  Bank account or service
# 4      1298081    2015-03-24  Bank account or service
#
#                   sub_product                                    issue  \
# 0            Checking account                Using a debit or ATM card
# 1            Checking account  Account opening, closing, or management
# 2  Other bank product/service                 Deposits and withdrawals
# 3  Other bank product/service  Account opening, closing, or management
# 4  Other bank product/service  Account opening, closing, or management
#
#   sub_issue                       consumer_complaint_narrative  \
# 0      None  I 'm no longer an account holder of SunTrust. ...
# 1      None  After banking with Citibank for over 3 years, ...
# 2      None  On XXXX XXXX I went to the Citizens Bank on XX...
# 3      None  The following summarizes my issue with PNC Ban...
# 4      None  This is a concern with companies in general. T...
#
#                             company_public_response  \
# 0  Company chooses not to provide a public response
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                              None
#
#                           company state zip_code            tags  \
# 0            SunTrust Banks, Inc.    FL    334XX            None
# 1                        Citibank    TX    797XX            None
# 2  Citizens Financial Group, Inc.    MA    021XX            None
# 3                   PNC Bank N.A.    MI    493XX  Older American
# 4                     Capital One    CA    906XX            None
#
#   consumer_consent_provided submitted_via   date_sent  \
# 0          Consent provided           Web  2015-03-24
# 1          Consent provided           Web  2015-03-24
# 2          Consent provided           Web  2015-03-24
# 3          Consent provided           Web  2015-03-30
# 4          Consent provided           Web  2015-03-24
#
#   company_response_to_consumer timely_response consumer_disputed
# 0      Closed with explanation             Yes                No
# 1      Closed with explanation             Yes                No
# 2      Closed with explanation             Yes                No
# 3      Closed with explanation             Yes                No
# 4      Closed with explanation             Yes                No
